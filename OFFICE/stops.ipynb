# %%
import pymysql
import pandas as pd

connection=pymysql.connect(
    host="s13.hosterpk.com",
    user="pakis104_owaisJaved",
    password="Developers123@",
    database="pakis104_oee_kompass"
)
df_c = pd.read_sql_query("SELECT * FROM CompleteOrders", connection)
df_d = pd.read_sql_query("SELECT * FROM DeviceData", connection)
print(df_c)
print(df_d)
connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pymysql
#       2 import pandas as pd
# ----> 4 connection=pymysql.connect(
#       5     host="s13.hosterpk.com",
#       6     user="pakis104_owaisJaved",
#       7     password="Developers123@",
#       8     database="pakis104_oee_kompass"
#       9 )
#      10 df_c = pd.read_sql_query("SELECT * FROM CompleteOrders", connection)
#      11 df_d = pd.read_sql_query("SELECT * FROM DeviceData", connection)
#
# ...

# %%
df_running.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3000 non-null   int64
#  1   startTime        0 non-null      object
#  2   endTime          0 non-null      object
#  3   uptime           0 non-null      object
#  4   orderStart       0 non-null      object
#  5   orderEnd         0 non-null      object
#  6   childDeviceName  0 non-null      object
#  7   deviceName       0 non-null      object
#  8   shiftName        0 non-null      object
#  9   shiftStartTime   0 non-null      object
#  10  shiftEndTime     0 non-null      object
#  11  deviceDataId     0 non-null      object
#  12  orderId          0 non-null      object
# dtypes: int64(1), object(12)
# memory usage: 304.8+ KB

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     201 non-null    int64
#  1   deviceName             201 non-null    object
#  2   productCount           201 non-null    int64
#  3   deviceStatus           201 non-null    int64
#  4   poNumber               201 non-null    object
#  5   skuName                201 non-null    object
#  6   skuTarget              201 non-null    int64
#  7   shiftName              201 non-null    object
#  8   teamName               201 non-null    object
#  9   distributerName        201 non-null    object
#  10  plannedStart           201 non-null    object
#  11  plannedEnd             201 non-null    object
#  12  orderCompletionStatus  201 non-null    int64
#  13  shippableProduct       201 non-null    int64
# ...

# %%
df_running=pd.DataFrame(columns=["id","startTime","endTime","uptime","orderStart","orderEnd","childDeviceName","deviceName","shiftName","shiftStartTime","shiftEndTime","deviceDataId","orderId"])

df_running["id"]=range(3000)

# %%
df_running['childDeviceName']="MiraFlex 1"
df_running['deviceName']="MiraFlex 1"
j=0
for i in range(len(df_c)):
    df_running.iloc[j,12]=df_c.iloc[i,17]
    df_running.iloc[j,4]=df_c.iloc[i,10]
    df_running.iloc[j,5]=df_c.iloc[i,11]
    #df_running.iloc[j,3]=df_c.iloc[i,16]
    df_running.iloc[j,8]=df_c.iloc[i,7]
    df_running.iloc[j,9]=df_c.iloc[i,18]
    df_running.iloc[j,10]=df_c.iloc[i,19]
    #df_running.iloc[j,22]=df_c.iloc[i,5]
    df_combine = pd.merge(df_running, df_d, left_on="orderId", right_on="orderId", how="inner", suffixes=("_running", "_d"))
    last=0
    
    for k in range(len(df_combine)): 
        if ((str(df_running.iloc[j,4])<=df_combine.iloc[k,24]) and (df_running.iloc[j,5]>=df_combine.iloc[k,24])):
            current=df_combine.iloc[k,15]
            if ((current!=last)and(current==1)):
                df_running.iloc[j,1]=df_combine.iloc[k,24]
                j+=1   
            if ((current!=last)and(current==0)): 
                df_running.iloc[j,2]=df_combine.iloc[k,24]
            last=df_combine.iloc[k,15] 
              
#df_combine

# %%
df_stops.to_csv("stops1.csv")

# %%
df_combine
# Out:
#        id_running startTime endTime uptime           orderStart  \
# 0               0       NaN     NaN    NaN  04/09/2024 07:00:07
# 1               0       NaN     NaN    NaN  04/09/2024 07:00:07
# 2               0       NaN     NaN    NaN  04/09/2024 07:00:07
# 3               0       NaN     NaN    NaN  04/09/2024 07:00:07
# 4               0       NaN     NaN    NaN  04/09/2024 07:00:07
# ...           ...       ...     ...    ...                  ...
# 68620           0       NaN     NaN    NaN  04/09/2024 07:00:07
# 68621           0       NaN     NaN    NaN  04/09/2024 07:00:07
# 68622           0       NaN     NaN    NaN  04/09/2024 07:00:07
# 68623           0       NaN     NaN    NaN  04/09/2024 07:00:07
# 68624           0       NaN     NaN    NaN  04/09/2024 07:00:07
#
#                   orderEnd childDeviceName deviceName_running shiftName  \
# 0      04/09/2024 14:46:31      MiraFlex 1         MiraFlex 1         A
# ...

# %%
df_stops
# Out:
#         id startTime endTime downtime           orderStart  \
# 0        0       NaN     NaN      550  12/21/2023 12:48:18
# 1        1       NaN     NaN      NaN                  NaN
# 2        2       NaN     NaN      NaN                  NaN
# 3        3       NaN     NaN      NaN                  NaN
# 4        4       NaN     NaN      NaN                  NaN
# ...    ...       ...     ...      ...                  ...
# 2995  2995       NaN     NaN      NaN                  NaN
# 2996  2996       NaN     NaN      NaN                  NaN
# 2997  2997       NaN     NaN      NaN                  NaN
# 2998  2998       NaN     NaN      NaN                  NaN
# 2999  2999       NaN     NaN      NaN                  NaN
#
#                  orderEnd stopUpdatedTime stopUpdatedBy categoryName causeOne  \
# 0     12/21/2023 13:58:59             NaN           NaN    Unplanned      NaN
# 1                     NaN             NaN           NaN    Unplanned      NaN
# ...

# %%
import pymysql
import pandas as pd

connection=pymysql.connect(
    host="s13.hosterpk.com",
    user="pakis104_owaisJaved",
    password="Developers123@",
    database="pakis104_oee_kompass"
)
df_c = pd.read_sql_query("SELECT * FROM CompleteOrders", connection)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17656\1457371205.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_c = pd.read_sql_query("SELECT * FROM CompleteOrders", connection)

# %%
df_c
# Out:
#       id  deviceName  productCount  deviceStatus poNumber     skuName  \
# 0    416  MiraFlex 1        108406             0   619815   PET (400)
# 1    417  MiraFlex 1        153709             0   619815   PET (400)
# 2    418  MiraFlex 1        189824             0   619815   PET (400)
# 3    419  MiraFlex 1        189824             0   619815   PET (400)
# 4    420  MiraFlex 1        193779             0   619815   PET (400)
# ..   ...         ...           ...           ...      ...         ...
# 196  618  MiraFlex 1             0             0   118289  LDPE (400)
# 197  619  MiraFlex 1         72600             1   118289  LDPE (400)
# 198  620  MiraFlex 1        106758             0   118289  LDPE (400)
# 199  621  MiraFlex 1         97482             0   118289  LDPE (400)
# 200  622  MiraFlex 1         50386             0   118289  LDPE (400)
#
#      skuTarget shiftName teamName distributerName         plannedStart  \
# ...

# %%
#df=pd.ExcelFile("stop1.xlsx")
#df.to_excel("stops1.xlsx")

#df=df.rename(columns={'Unnamed: 0': 'id'})
df
# Out:
#                      startTime                   endTime  downTime  \
# 0     2024-02-01T15:00:09.000Z  2024-02-01T15:33:10.000Z      1981
# 1     2024-02-01T15:40:31.000Z  2024-02-01T15:46:10.000Z       339
# 2     2024-02-01T15:46:50.000Z  2024-02-01T16:07:11.000Z      1221
# 3     2024-02-01T16:07:51.000Z  2024-02-01T16:09:30.000Z        99
# 4     2024-02-01T16:10:30.000Z  2024-02-01T16:47:01.000Z      2191
# ...                        ...                       ...       ...
# 2410  2024-04-08T18:23:21.000Z  2024-04-08T18:26:41.000Z       200
# 2411  2024-04-08T18:43:21.000Z  2024-04-08T19:53:41.000Z      4220
# 2412  2024-04-08T20:53:02.000Z  2024-04-08T20:56:42.000Z       220
# 2413  2024-04-08T21:03:42.000Z  2024-04-08T21:23:02.000Z      1160
# 2414  2024-04-08T22:00:02.000Z  2024-04-08T22:13:23.000Z       801
#
#       deviceDataId     Status           orderStart             orderEnd  \
# 0           348015  Completed  02/01/2024 15:00:09  02/01/2024 22:59:43
# ...

# %%
connection=pymysql.connect(
    host="s13.hosterpk.com",
    user="pakis104_owaisJaved",
    password="Developers123@",
    database="pakis104_oee_kompass"
)
df_s = pd.read_sql_query("SELECT * FROM Stops", connection)
df_s
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17656\885771799.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_s = pd.read_sql_query("SELECT * FROM Stops", connection)
#         id                 startTime                   endTime  downTime  \
# 0     3636  2024-02-01T15:00:09.000Z  2024-02-01T15:33:10.000Z      1981
# 1     3637  2024-02-01T15:40:31.000Z  2024-02-01T15:46:10.000Z       339
# 2     3638  2024-02-01T15:46:50.000Z  2024-02-01T16:07:11.000Z      1221
# 3     3639  2024-02-01T16:07:51.000Z  2024-02-01T16:09:30.000Z        99
# 4     3640  2024-02-01T16:10:30.000Z  2024-02-01T16:47:01.000Z      2191
# ...    ...                       ...                       ...       ...
# 2410  6046  2024-04-08T18:23:21.000Z  2024-04-08T18:26:41.000Z       200
# ...
